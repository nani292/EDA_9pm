# %% [markdown]
# - Variables
#
# - Data Type
#
# - Type Casting
#
# - Print Statement
#
# - Input and Round
#
# - We perform the basic 3 ways
#
#       - Using proper variables
#
#       - Using print statement
#
#       - Using input and round functions

# %%
# import <module_name>
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import <module_name>
# ----> 2 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %% [markdown]
# **moudle**
#
# - Moudle is a single python file
#
# - Having variable, function, calsses, methods,
#
# **packges**
#
# - packges contains multiple python file
#
# -Assume that python has created 4 python files
#
#           - addition.py
#
#           - subtraction.py
#
#           - multiplication.py
#
#           - divion.py
#
# - All this 4 python files can save into a packges

# %%
math_funtions
    add.py
    sub.py
    mup.py
    div.py
from math_functions import add
from math_fuctions import sub
from math_functions import mul
from math_functions import div 
from mat_functions import add,sub,mul,div.

# %% [markdown]
# **random**

# %%
import random 
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# step-1: import <module name>
# step-2: dir(<module name>)
import <moudle name>
import <random>   # wrong
import random     # correct

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
# ...

# %%
import random     # correct
dir(random)       # correct

import<random>        # wrong
dir(import random)    # wrong

# %%
import

# %%
# moudle    method
# random    random
# random    choice
# random    shuffle
# math      e
# math      pi
# math      sqrt
# math      pow
# time      sleep

# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
help(math.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN\\OneDrive.ada7d9e3-0e7f-44d8-a811-028865040d70'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'session_5_packges.ipynb', 'shashank', 'Untitled.ipynb']

# %%
import math
math.ceil(20)
# Out:
# 20

# %%
import random
l=[10,20,30,40,50]
random.choice(l)
# Out:
# 40

# %%
import time
time.sleep
# Out:
# <function time.sleep(object, /)>

# %%
time.sleep(5)
print('good eve')
# Out:
# good eve

# %%
math.ceil(40.7896)
# Out:
# 41

# %%
math.ceil(40.1234)
# Out:
# 41

# %%
import time
start=time.time()
time.sleep(5)
print('good evening')
end=time.time()
end-start
# Out:
# good evening
# 5.001555442810059

# %%
os.makedirs('shashank')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 os.makedirs('shashank')
#
# File ~\AppData\Local\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'shashank'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'session_5_packges.ipynb', 'shashank', 'Untitled.ipynb']

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.Formatter()

# %%
string._ChainMap()
# Out:
# ChainMap({})

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.digits
# Out:
# '0123456789'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.octdigits
# Out:
# '01234567'

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
import random
random.randint(10,20)
# Out:
# 13

# %%
from random import randint
randint(10,20)
# Out:
# 17

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\ADMIN\\AppData\\Local\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2

# %%
import langchain

# %%
import shashank

# %%
import nani
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import nani
#
# ModuleNotFoundError: No module named 'nani'

# %%
import langchain

# %%
import cv2

# %% [markdown]
# - Pip install module name
#
# - Copy paste the error in the google
#
# - Search PyPI organization
#
# - Copy and paste run it

# %%
import langgraph

# %%
import tensorflow

# %%
pip freeze
# Out:
# absl-py==2.3.1
# aiobotocore @ file:///C:/b/abs_431uzunk2v/croot/aiobotocore_1738237882529/work
# aiohappyeyeballs @ file:///C:/b/abs_e9fm5mk6ak/croot/aiohappyeyeballs_1734469429350/work
# aiohttp @ file:///C:/b/abs_d4_gdjffav/croot/aiohttp_1734687146788/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# alabaster @ file:///C:/Users/dev-admin/perseverance-python-buildout/croot/alabaster_1729041938345/work
# altair @ file:///C:/b/abs_0b1avjyzoc/croot/altair_1743016738596/work
# anaconda-anon-usage @ file:///C:/b/abs_1az9wuczyu/croot/anaconda-anon-usage_1749054795139/work
# anaconda-auth @ file:///C:/b/abs_66s84uss7v/croot/anaconda-cloud-auth-split_1747863792543/work
# anaconda-catalogs @ file:///C:/b/abs_ac59ma63va/croot/anaconda-catalogs_1747774731997/work
# anaconda-cli-base @ file:///C:/b/abs_e4_l2p3q_7/croot/anaconda-cli-base_1741369468349/work
# ...

# %%
import tensorflow

# %%
import tensorflow
