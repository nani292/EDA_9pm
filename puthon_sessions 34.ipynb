# %%
# wap takes 3 variables a,b,c
# provide the values 
# find average

# %%
a=100
b=200
c=300
average=(a+b+c)//3
print(average)
# Out:
# 200

# %%
wap take the calculate area of circle 
pi=3.14 r 
formula = pi*r*r


wap ask the user 
take bill amount and tip amount 
calcualte total bill
total bill= bill amount+tip amount

# %%
pi=3.14
radius =9
area  = pi*radius*radius 
print(area)
# Out:
# 254.34

# %%
a=1000
b=100
total_bill= a+b
print (total_bill)
# Out:
# 1100

# %%
a=180   #weight
pound= a*2.2
print("pound",pound)
# Out:
# pound 396.00000000000006

# %%
rupee=100
indian_currency=80*rupee
indian_currency
#print(indian_currency)
# Out:
# 8000

# %%
# 2pi*r  calculate thre circumference of circle 
pi=3.14
radius=90
circumference =pi*pi*radius
print ("circumference =",+circumference)
area=pi*radius*radius
area
# Out:
# circumference = 887.364
# 25434.000000000004

# %%
#area =pirsquare
#pi*(d/2)2
#area of circle ?

d=100
pi=3.14
area = 3.14*(50**2)
print(area)
# Out:
# 7850.0

# %%
diameter = float(input("Enter the diameter of the circle: "))

# radius is half of diameter
radius = diameter / 2

# formula for area = π × r²
area = 3.14159 * (radius ** 2)

print("The area of the circle is:", area)
# Out:
# Enter the diameter of the circle:  50
# The area of the circle is: 1963.4937499999999

# %%
#area=pi*r**2
radius =float(input("ener thr radicus od circle"))
#area=1963
pi=3.14
area= 3.14 * (radius*radius)

print("area of circle is:", area)
# Out:
# ener thr radicus od circle 3
# area of circle is: 28.26

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\OneDrive\\Documents\\Naresh IT\\data science\\python sessions'
